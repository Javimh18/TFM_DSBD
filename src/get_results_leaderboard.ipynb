# %%
import os
# Changing the working directory
os.chdir('..')
os.getcwd()
# Out:
# '/home/javiermunoz/Universidad/MasterBDyDS/TFM/TFM_DSBD'

# %%
import pandas as pd
import numpy as np

# %%
lb = pd.read_csv('data/leaderboard.csv')
lb
# Out:
#    model_type model_name  train_acc  val_acc  test_acc  train_loss  val_loss
# 0    convlstm     simple       0.96     0.93      0.93        0.15      0.20  \
# 1    convlstm  stateless       0.93     0.95      0.91        0.22      0.19
# 2   mediapipe         mp       0.90     0.90      0.87        0.27      0.35
# 3   mediapipe         mp       0.89     0.85      0.85        0.38      0.62
# 4   mediapipe         mp       0.93     0.86      0.86        0.24      0.63
# 5       3DCNN      3dcnn       0.93     0.92      0.91        0.33      0.37
# 6    convlstm  stateless       0.90     0.94      0.92        0.27      0.24
# 7    convlstm  stateless       0.95     0.92      0.82        0.20      0.26
# 8    convlstm  stateless       0.87     0.77      0.74        0.38      1.05
# 9    convlstm     simple       0.83     0.65      0.65        0.48      1.36
# 10      3DCNN      3dcnn       0.91     0.91      0.88        0.45      0.50
# ...

# %%
lb[(lb.model_type == 'mediapipe') & (lb.model_name == 'mp')].sort_values('subset_size', ascending=True)
# Out:
#    model_type model_name  train_acc  val_acc  test_acc  train_loss  val_loss
# 2   mediapipe         mp       0.90     0.90      0.87        0.27      0.35  \
# 4   mediapipe         mp       0.93     0.86      0.86        0.24      0.63
# 3   mediapipe         mp       0.89     0.85      0.85        0.38      0.62
# 11  mediapipe         mp       0.91     0.84      0.04        0.30      0.57
#
#     test_loss  epoch                                      path_to_model
# 2        0.54  178.0  src/mediapipe/bestmodels/best_mp_178_0.90_20_m...  \
# 4        0.55  167.0  src/mediapipe/bestmodels/best_mp_167_0.86_30_m...
# 3        0.43  159.0  src/mediapipe/bestmodels/best_mp_159_0.85_40_m...
# 11      13.18  168.0  src/mediapipe/bestmodels/best_mp_168_0.84_50_m...
#
#     subset_size
# 2          20.0
# 4          30.0
# 3          40.0
# 11         50.0

# %%
lb[(lb.model_type == '3DCNN') & (lb.model_name == '3dcnn')].sort_values('subset_size', ascending=True)
# Out:
#    model_type model_name  train_acc  val_acc  test_acc  train_loss  val_loss
# 14      3DCNN      3dcnn       0.92     0.91      0.88        0.45      0.50  \
# 5       3DCNN      3dcnn       0.93     0.92      0.91        0.33      0.37
# 15      3DCNN      3dcnn       0.91     0.95      0.91        0.39      0.31
# 10      3DCNN      3dcnn       0.91     0.91      0.88        0.45      0.50
#
#     test_loss  epoch                                      path_to_model
# 14       0.57   63.0  src/3DCNN/bestmodels/best_3dcnn_135_0.90_10_mo...  \
# 5        0.40  132.0  src/3DCNN/bestmodels/best_3dcnn_132_0.92_20_20...
# 15       0.37  148.0  src/3DCNN/bestmodels/best_3dcnn_148_0.95_30_mo...
# 10       0.57  135.0  src/3DCNN/bestmodels/best_3dcnn_135_0.91_40_mo...
#
#     subset_size
# 14         10.0
# 5          20.0
# 15         30.0
# 10         40.0

# %%
lb[(lb.model_type == 'convlstm') & (lb.model_name == 'simple')].sort_values('subset_size', ascending=True)
# Out:
#    model_type model_name  train_acc  val_acc  test_acc  train_loss  val_loss
# 0    convlstm     simple       0.96     0.93      0.93        0.15      0.20  \
# 12   convlstm     simple       0.94     0.93      0.89        0.15      0.26
# 13   convlstm     simple       0.91     0.89      0.85        0.26      0.38
# 9    convlstm     simple       0.83     0.65      0.65        0.48      1.36
#
#     test_loss  epoch                                      path_to_model
# 0        0.19   39.0  src/convlstm/bestmodels/best_simple_39_0.93_10...  \
# 12       0.36   72.0  src/convlstm/bestmodels/best_simple_72_0.93_20...
# 13       0.52   96.0  src/convlstm/bestmodels/best_simple_96_0.89_30...
# 9        1.27  170.0  src/convlstm/bestmodels/best_simple_170_0.65_4...
#
#     subset_size
# 0          10.0
# 12         20.0
# 13         30.0
# 9          40.0

# %%
lb[(lb.model_type == 'convlstm') & (lb.model_name == 'stateless')].sort_values('subset_size', ascending=True)
# Out:
#   model_type model_name  train_acc  val_acc  test_acc  train_loss  val_loss
# 1   convlstm  stateless       0.93     0.95      0.91        0.22      0.19  \
# 6   convlstm  stateless       0.90     0.94      0.92        0.27      0.24
# 7   convlstm  stateless       0.95     0.92      0.82        0.20      0.26
# 8   convlstm  stateless       0.87     0.77      0.74        0.38      1.05
#
#    test_loss  epoch                                      path_to_model
# 1       0.19   22.0  src/convlstm/bestmodels/best_stateless_22_0.95...  \
# 6       0.22   63.0  src/convlstm/bestmodels/best_stateless_63_0.94...
# 7       0.46   93.0  src/convlstm/bestmodels/best_stateless_91_0.92...
# 8       1.06  104.0  src/convlstm/bestmodels/best_stateless_104_0.7...
#
#    subset_size
# 1         10.0
# 6         20.0
# 7         30.0
# 8         40.0
